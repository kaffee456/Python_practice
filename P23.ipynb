# %%
from sympy import *
x = symbols('x')
init_printing()
Integral(sqrt(1/(x**2)),x)
# Out:
# ⌠
# ⎮      ____
# ⎮     ╱ 1
# ⎮    ╱  ──  dx
# ⎮   ╱    2
# ⎮ ╲╱    x
# ⌡

# %%
y = symbols('y')
exp2 = (x**2-y**2)/(x-y)
exp2
# Out:
#  2    2
# x  - y
# ───────
#  x - y

# %%
cancel(exp2)
# Out:
# x + y

# %%
x = symbols('x')
plot(-x**4 + x*2 -10)

# %%
from bokeh.plotting import figure, output_file, show
import numpy as np

x = np.arange(1, 10.0, 0.1)
output_file("cubic.html")
p = figure(title="反比例曲線", x_axis_label='x',y_axis_label='1/x')
p.line(x,1/x)
show(p)

# %%
from sympy import *
x = symbols('x')
init_printing()
Integral(sqrt(1/x),x)
# Out:
# ⌠
# ⎮     ___
# ⎮    ╱ 1
# ⎮   ╱  ─  dx
# ⎮ ╲╱   x
# ⌡

# %%
plot(1/x)

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8,8)

plot_implicit(x**2+y**2-9)

# %%
Rational(3,2)
# Out:
# 3/2

# %%
# Figureサイズを8×8に設定
plt.rcParams['figure.figsize'] = 8, 8

# sympyから必要な関数をインポート
from sympy import var, cos, sin

# plot3d_parametric_surface()をppsという名前でインポート
from sympy.plotting import plot3d_parametric_surface as pps

# 記号を定義
var('u v')

# 球面方程式のパラメータ表示
x = 3*sin(u) * cos(v)
y = 3*sin(u) * sin(v)
z = 3*cos(u)

# 球面を描画
p = pps(x, y, z, (u, 0, 8), (v, 0, 8))
